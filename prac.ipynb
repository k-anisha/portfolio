# %%
import pandas as pd

# %%
def funcy(x):
    return 'bello' \
        + x

def func(y):
    return 'bello' + y

# %%
func('r')
# Out:
# 'bellor'

# %%
def funky():
    """
    outputs bello
    >>> funky()
    'bello'  
    """
    print('bello')

# %%
lec_4_6 = pd.read_csv('/Users/k_anisha/Library/CloudStorage/OneDrive-Personal/UCSD/YEAR 2/SPRING 2026/Toot/grades-dsc/data/4_6.csv')

# %%
lec_4_6
# Out:
#                    Email   Last Name First Name Session 4 Unnamed: 4  \
# 0                    NaN         NaN        NaN       NaN        NaN
# 1   abhawsingka@ucsd.edu  Bhawsingka      Advay         B          D
# 2         achon@ucsd.edu        Chon     Andrew       NaN        NaN
# 3   agillgulati@ucsd.edu        Gill      Arran         E          D
# 4       akharya@ucsd.edu      Kharya     Ananya         C          A
# ..                   ...         ...        ...       ...        ...
# 73       ykayal@ucsd.edu       Kayal     Yasmin         B          D
# 74         ysok@ucsd.edu         Sok      Yejin         B          D
# 75       yug082@ucsd.edu         Guo      Jenny         B          D
# 76       yuw314@ucsd.edu        Wang      Yurui         B          A
# 77      z8shang@ucsd.edu       Shang  Zhancheng         B          B
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0         NaN        NaN        NaN
# 1           B          D          A
# ...

# %%
cols = lec_4_6.columns[-5:]
lec_4_6[cols] = lec_4_6[cols].notna().astype(int)
lec_4_6['sum'] = lec_4_6[cols].sum(axis=1)
lec_4_6['avg'] = lec_4_6['sum'] / 5

# %%
print(list(lec_4_6[lec_4_6['avg'] > 0.6]['Email']))
# Out:
# ['abhawsingka@ucsd.edu', 'agillgulati@ucsd.edu', 'akharya@ucsd.edu', 'ala036@ucsd.edu', 'alp027@ucsd.edu', 'amvelivelli@ucsd.edu', 'anr082@ucsd.edu', 'ant072@ucsd.edu', 'aswarrier@ucsd.edu', 'atakkallapalli@ucsd.edu', 'atyuen@ucsd.edu', 'avinh@ucsd.edu', 'avlin@ucsd.edu', 'bpurugganan@ucsd.edu', 'chc240@ucsd.edu', 'cwgee@ucsd.edu', 'daf009@ucsd.edu', 'emazhou@ucsd.edu', 'eqiu@ucsd.edu', 'erl023@ucsd.edu', 'gerobin@ucsd.edu', 'goz001@ucsd.edu', 'haw150@ucsd.edu', 'haw152@ucsd.edu', 'j2venegas@ucsd.edu', 'jac151@ucsd.edu', 'jalkhardawi@ucsd.edu', 'jev001@ucsd.edu', 'jijing@ucsd.edu', 'jug050@ucsd.edu', 'keumali@ucsd.edu', 'kjagdish@ucsd.edu', 'kjferreira@ucsd.edu', 'l8guo@ucsd.edu', 'laceves@ucsd.edu', 'mfloresgomez@ucsd.edu', 'n3ding@ucsd.edu', 'nmayrhoferchechnev@ucsd.edu', 'nomprakash@ucsd.edu', 'o2zhang@ucsd.edu', 'q2truong@ucsd.edu', 'qiz089@ucsd.edu', 'rbmarcus@ucsd.edu', 'rystanley@ucsd.edu', 'sabhargava@ucsd.edu', 'saosorio@ucsd.edu', 'sdinova@ucsd.edu', 'sgriffiths@ucsd.edu', 
# ...

# %%
x, y, z = 1, 2, 3

# %%
type((0))
# Out:
# int

# %%
x = (1, 2, 'a', [1])

# %%
type(x)
# Out:
# tuple
